# %% [markdown]
# # Knapsack Problem Exercises
# This notebook uses the Julia programming language to solve the exercises, the cells bellow will explain how to install the Julia kernel and packages.

# %% [markdown]
# ### Julia enviroment

# %% [markdown]
# To start off, you should have Julia install in your operating system. After that, you'll have to install the Julia package that provides the Julia kernel for this notebook. You can do this by running
# ```julia
# using Pkg; Pkg.add("IJulia")
# ```
# in the Julia REPL.

# %% [markdown]
# With the kernel installed, we can continue by installing the packages related to the JuMP modeling language. Running the commands bellow in the Julia REPL will install the needed packages JuMP, HiGHS and Combinatorics.
# ```julia
# using Pkg; Pkg.add("JuMP"); Pkg.add("HiGHS"); Pkg.add("Combinatorics")
# ```

# %%
using JuMP
import HiGHS
using Combinatorics

include("check_exercise.jl");

# %% [markdown]
# The cell above imports the packages you just downloaded and includes a file that contains functions to check the correctness of the solution you proposed on the exercises.

# %% [markdown]
# ## Exercises

# %% [markdown]
# With the Julia and JuMP enviroment working, you are now able to solve the knapsack exercises presented in the book. At each exercise, a standard model of the knapsack problem and you'll have to add the right constraints. After adding your constraint you can run the cell right bellow the model to check if your solution is correct. The cell bellow contains the instance used in the exercises 1 to 3.

# %%
n = 7;
capacity = 50;

profits = [70, 20, 39, 37, 7, 5, 10];
weights = [31, 10, 20, 19, 4, 3, 6];

# %% [markdown]
# ### Exercise 1
# Modify the KP formulation to address a case where two arbitrary items $j,k \in \{1,\dots,n\}$ are linked so that if $j$ is included in the knapsack, so must be $k$. In other words, solutions where $x_j = 1$ and $x_k = 0$ must not be allowed.

# %%
function knapsack_ex1(n::Int, capacity::Int, profits::Vector{Int}, weights::Vector{Int}, test::Vector{Int})
    
    tests = generate_partitions(n);
    
    j = 1
    k = 2

    model = Model(HiGHS.Optimizer);
    
    @variable(model, x[1:n], Bin);
    set_silent(model);
    @constraint(model, sum(weights[i] * x[i] for i in 1:n) <= capacity);
    #Add your constraints here
    
    
    @objective(model, Max, sum(profits[i] * x[i] for i in 1:n));

    set_test(model, test, n, x);
    
    optimize!(model);
    return termination_status(model);
end;

# %%
check_exercise(knapsack_ex1, n, capacity, profits, weights, 1)
# Out:
# Erro in test: [1]
# Expected: INFEASIBLE, Got: OPTIMAL
#
# Wrong Answer - 93% of all tests passed.

# %% [markdown]
# ### Exercise 2
# Same as the previous Exercise, but this time, items $j$ and $k$ are mutually exclusive, i.e., they can not be included together in the knapsack.

# %%
function knapsack_ex2(n::Int, capacity::Int, profits::Vector{Int}, weights::Vector{Int}, test::Vector{Int})
    
    tests = generate_partitions(n);
    
    j = 1
    k = 2

    model = Model(HiGHS.Optimizer);
    
    @variable(model, x[1:n], Bin);
    set_silent(model);
    @constraint(model, sum(weights[i] * x[i] for i in 1:n) <= capacity);
    #Add your constraints here
    @constraint(model, x[j] + x[k] <= 0.5)
    
    
    @objective(model, Max, sum(profits[i] * x[i] for i in 1:n));

    set_test(model, test, n, x);
    
    optimize!(model);
    return termination_status(model);
end;

# %%
check_exercise(knapsack_ex2, n, capacity, profits, weights, 2)
# Out:
# Erro in test: [1]
# Expected: OPTIMAL, Got: INFEASIBLE
#
# Wrong Answer - 73% of all tests passed.

# %% [markdown]
# ### Exercises 3
# Modify the KP formulation so that an arbitrary item $l$ must be included in the knapsack if and only if both $j$ and $k$ are. (This could be achieved by adding the equality $x_l = x_jx_k$, but only linear inequalities (or equalities) are allowed).

# %%
function knapsack_ex3(n::Int, capacity::Int, profits::Vector{Int}, weights::Vector{Int}, test::Vector{Int})
    
    tests = generate_partitions(n);
    
    j = 1
    k = 2
    l = 3
    model = Model(HiGHS.Optimizer);
    
    @variable(model, x[1:n], Bin);
    set_silent(model);
    @constraint(model, sum(weights[i] * x[i] for i in 1:n) <= capacity);
    #Add your constraints here
    @constraint(model, x[l] <= x[j])
    @constraint(model, x[l] <= x[k])
    @constraint(model, x[l] >= x[j] + x[k] - 1)
    
    @objective(model, Max, sum(profits[i] * x[i] for i in 1:n));

    set_test(model, test, n, x);
    
    optimize!(model);
    return termination_status(model);
end;

# %%
check_exercise(knapsack_ex3, n, capacity, profits, weights, 3)
# Out:
# All Tests Passed!!
